# %%
# Cargar los elementos 
elementos = {

    # Grupo 1 (Metales alcalinos)
    'hidrogeno': {'numero': 1, 'simbolo': 'H', 'masa': 1.008, 'grupo': 1, 'periodo': 1, 'estado': 'Gas', 'tipo': 'No metal', 'config': '1s¹'},
    'litio': {'numero': 3, 'simbolo': 'Li', 'masa': 6.94, 'grupo': 1, 'periodo': 2, 'estado': 'Sólido', 'tipo': 'Metal alcalino', 'config': '2s¹'},
    'sodio': {'numero': 11, 'simbolo': 'Na', 'masa': 22.990, 'grupo': 1, 'periodo': 3, 'estado': 'Sólido', 'tipo': 'Metal alcalino', 'config': '3s¹'},
    'potasio': {'numero': 19, 'simbolo': 'K', 'masa': 39.098, 'grupo': 1, 'periodo': 4, 'estado': 'Sólido', 'tipo': 'Metal alcalino', 'config': '4s¹'},
    'rubidio': {'numero': 37, 'simbolo': 'Rb', 'masa': 85.468, 'grupo': 1, 'periodo': 5, 'estado': 'Sólido', 'tipo': 'Metal alcalino', 'config': '5s¹'},
    'cesio': {'numero': 55, 'simbolo': 'Cs', 'masa': 132.91, 'grupo': 1, 'periodo': 6, 'estado': 'Sólido', 'tipo': 'Metal alcalino', 'config': '6s¹'},
    'francio': {'numero': 87, 'simbolo': 'Fr', 'masa': 223, 'grupo': 1, 'periodo': 7, 'estado': 'Sólido', 'tipo': 'Metal alcalino', 'config': '7s¹'},

    # Grupo 2 (Metales alcalinotérreos)
    'berilio': {'numero': 4, 'simbolo': 'Be', 'masa': 9.0122, 'grupo': 2, 'periodo': 2, 'estado': 'Sólido', 'tipo': 'Metal alcalinotérreo', 'config': '2s²'},
    'magnesio': {'numero': 12, 'simbolo': 'Mg', 'masa': 24.305, 'grupo': 2, 'periodo': 3, 'estado': 'Sólido', 'tipo': 'Metal alcalinotérreo', 'config': '3s²'},
    'calcio': {'numero': 20, 'simbolo': 'Ca', 'masa': 40.078, 'grupo': 2, 'periodo': 4, 'estado': 'Sólido', 'tipo': 'Metal alcalinotérreo', 'config': '4s²'},
    'estroncio': {'numero': 38, 'simbolo': 'Sr', 'masa': 87.62, 'grupo': 2, 'periodo': 5, 'estado': 'Sólido', 'tipo': 'Metal alcalinotérreo', 'config': '5s²'},
    'bario': {'numero': 56, 'simbolo': 'Ba', 'masa': 137.33, 'grupo': 2, 'periodo': 6, 'estado': 'Sólido', 'tipo': 'Metal alcalinotérreo', 'config': '6s²'},
    'radio': {'numero': 88, 'simbolo': 'Ra', 'masa': 226, 'grupo': 2, 'periodo': 7, 'estado': 'Sólido', 'tipo': 'Metal alcalinotérreo', 'config': '7s²'},

      # Grupo 3 (Escandioideos)
    'escandio': {'numero': 21, 'simbolo': 'Sc', 'masa': 44.956, 'grupo': 3, 'periodo': 4, 'estado': 'Sólido', 'tipo': 'Metal de transición', 'config': '3d¹ 4s²'},
    'itrio': {'numero': 39, 'simbolo': 'Y', 'masa': 88.906, 'grupo': 3, 'periodo': 5, 'estado': 'Sólido', 'tipo': 'Metal de transición', 'config': '4d¹ 5s²'},
    'lantano': {'numero': 57, 'simbolo': 'La', 'masa': 138.91, 'grupo': 3, 'periodo': 6, 'estado': 'Sólido', 'tipo': 'Lantánido', 'config': '5d¹ 6s²'},
    'actinio': {'numero': 89, 'simbolo': 'Ac', 'masa': 227, 'grupo': 3, 'periodo': 7, 'estado': 'Sólido', 'tipo': 'Actínido', 'config': '6d¹ 7s²'},

    # Grupo 4 (Titanioideos)
    'titanio': {'numero': 22, 'simbolo': 'Ti', 'masa': 47.867, 'grupo': 4, 'periodo': 4, 'estado': 'Sólido', 'tipo': 'Metal de transición', 'config': '3d² 4s²'},
    'circonio': {'numero': 40, 'simbolo': 'Zr', 'masa': 91.224, 'grupo': 4, 'periodo': 5, 'estado': 'Sólido', 'tipo': 'Metal de transición', 'config': '4d² 5s²'},
    'hafnio': {'numero': 72, 'simbolo': 'Hf', 'masa': 178.49, 'grupo': 4, 'periodo': 6, 'estado': 'Sólido', 'tipo': 'Metal de transición', 'config': '4f¹⁴ 5d² 6s²'},
    'rutherfordio': {'numero': 104, 'simbolo': 'Rf', 'masa': 267, 'grupo': 4, 'periodo': 7, 'estado': 'Sintético', 'tipo': 'Metal de transición', 'config': '5f¹⁴ 6d² 7s²'},

    # Grupo 5 (Vanadioideos)
    'vanadio': {'numero': 23, 'simbolo': 'V', 'masa': 50.942, 'grupo': 5, 'periodo': 4, 'estado': 'Sólido', 'tipo': 'Metal de transición', 'config': '3d³ 4s²'},
    'niobio': {'numero': 41, 'simbolo': 'Nb', 'masa': 92.906, 'grupo': 5, 'periodo': 5, 'estado': 'Sólido', 'tipo': 'Metal de transición', 'config': '4d⁴ 5s¹'},
    'tantalio': {'numero': 73, 'simbolo': 'Ta', 'masa': 180.95, 'grupo': 5, 'periodo': 6, 'estado': 'Sólido', 'tipo': 'Metal de transición', 'config': '4f¹⁴ 5d³ 6s²'},
    'dubnio': {'numero': 105, 'simbolo': 'Db', 'masa': 268, 'grupo': 5, 'periodo': 7, 'estado': 'Sintético', 'tipo': 'Metal de transición', 'config': '5f¹⁴ 6d³ 7s²'},

    # Grupo 6 (Cromoideos)
    'cromo': {'numero': 24, 'simbolo': 'Cr', 'masa': 51.996, 'tipo': 'Metal de transición', 'periodo': 4, 'estado': 'Sólido','grupo':6, 'config': '3d⁵ 4s¹'},
    'molibdeno': {'numero': 42, 'simbolo': 'Mo', 'masa': 95.95, 'tipo': 'Metal de transición', 'periodo': 5, 'estado': 'Sólido', 'grupo':6,'config': '4d⁵ 5s¹'},
    'wolframio': {'numero': 74, 'simbolo': 'W', 'masa': 183.84, 'tipo': 'Metal de transición', 'periodo': 6, 'estado': 'Sólido', 'grupo':6, 'config': '4f¹⁴ 5d⁴ 6s²'},
    'seaborgio': {'numero': 106, 'simbolo': 'Sg', 'masa': 271, 'tipo': 'Metal de transición', 'periodo': 7, 'estado': 'Desconocido', 'grupo':6, 'config': '5f¹⁴ 6d⁴ 7s²'},

       #Grupo 7(Manganesoideos)
    'manganeso': {'numero': 25, 'simbolo': 'Mn', 'masa': 54.938, 'tipo': 'Metal de transición', 'periodo': 4, 'estado': 'Sólido','grupo':7, 'config': '3d⁵ 4s²'},
    'tecnecio': {'numero': 43, 'simbolo': 'Tc', 'masa': 98, 'tipo': 'Metal de transición', 'periodo': 5, 'estado': 'Sólido', 'grupo':7,'config': '4d⁵ 5s²'},
    'renio': {'numero': 75, 'simbolo': 'Re', 'masa': 186.207, 'tipo': 'Metal de transición', 'periodo': 6, 'estado': 'Sólido','grupo':7, 'config': '4f¹⁴ 5d⁵ 6s²'},
    'bohrio': {'numero': 107, 'simbolo': 'Bh', 'masa': 270, 'tipo': 'Metal de transición', 'periodo': 7, 'estado': 'Desconocido', 'grupo':7, 'config': '5f¹⁴ 6d⁵ 7s²'},

    #Grupo 8 (Hierroideos)
    'hierro': {'numero': 26, 'simbolo': 'Fe', 'masa': 55.845, 'tipo': 'Metal de transición', 'periodo': 4, 'estado': 'Sólido', 'grupo':8,'config': '3d⁶ 4s²'},
    'rutenio': {'numero': 44, 'simbolo': 'Ru', 'masa': 101.07, 'tipo': 'Metal de transición', 'periodo': 5, 'estado': 'Sólido', 'grupo':8,'config': '4d⁷ 5s¹'},
    'osmio': {'numero': 76, 'simbolo': 'Os', 'masa': 190.23, 'tipo': 'Metal de transición', 'periodo': 6, 'estado': 'Sólido', 'grupo':8,  'config': '4f¹⁴ 5d⁶ 6s²'},
    'hassio': {'numero': 108, 'simbolo': 'Hs', 'masa': 277, 'tipo': 'Metal de transición', 'periodo': 7, 'estado': 'Desconocido', 'grupo':8,'config': '5f¹⁴ 6d⁶ 7s²'},

    #Grupo 9 (familia del cobalto)
    'cobalto': {'numero': 27, 'simbolo': 'Co', 'masa': 58.933, 'tipo': 'Metal de transición', 'periodo': 4, 'estado': 'Sólido', 'grupo':9,'config': '3d⁷ 4s²'},
    'rodio': {'numero': 45, 'simbolo': 'Rh', 'masa': 102.91, 'tipo': 'Metal de transición', 'periodo': 5, 'estado': 'Sólido', 'grupo':9,'config': '3d⁷ 4s²'},
    'iridio': {'numero': 77, 'simbolo': 'Ir', 'masa': 192.217, 'tipo': 'Metal de transición', 'periodo': 6, 'estado': 'Sólido', 'grupo':9, 'config': '4f¹⁴ 5d⁷ 6s²'},
    'meitnerio': {'numero': 109, 'simbolo': 'Mt', 'masa': 278, 'tipo': 'Metal de transición', 'periodo': 7, 'estado': 'Desconocido', 'grupo':9, 'config': '5f¹⁴ 6d⁷ 7s²'},

    #Grupo 10 (familia del níquel)
    'níquel': {'numero': 28, 'simbolo': 'Ni', 'masa': 58.693, 'tipo': 'Metal de transición', 'periodo': 4, 'estado': 'Sólido', 'grupo':10,'config': '3d⁸ 4s²'},
    'paladio': {'numero': 46, 'simbolo': 'Pd', 'masa': 106.42, 'tipo': 'Metal de transición', 'periodo': 5, 'estado': 'Sólido','grupo':10,'config': '4d¹⁰'},
    'platino': {'numero': 78, 'simbolo': 'Pt', 'masa': 195.084, 'tipo': 'Metal de transición', 'periodo': 6, 'estado': 'Sólido','grupo':10,'config': '4f¹⁴ 5d⁹ 6s¹'},
    'darmstadtio': {'numero': 110, 'simbolo': 'Ds', 'masa': 281, 'tipo': 'Metal de transición', 'periodo': 7, 'estado': 'Desconocido', 'grupo':10, 'config': '5f¹⁴ 6d⁹ 7s¹'},

    #Grupo 11 (familia del cobre)
    'cobre': {'numero': 29, 'simbolo': 'Cu', 'masa': 63.546, 'tipo': 'Metal de transición', 'periodo': 4, 'estado': 'Sólido', 'grupo':11,  'config': '3d¹⁰ 4s¹'},
    'plata': {'numero': 47, 'simbolo': 'Ag', 'masa': 107.87, 'tipo': 'Metal de transición', 'periodo': 5, 'estado': 'Sólido', 'grupo':11, 'config': '4d¹⁰ 5s¹'},
    'oro': {'numero': 79, 'simbolo': 'Au', 'masa': 196.966, 'tipo': 'Metal de transición', 'periodo': 6, 'estado': 'Sólido','grupo':11,'config': '4f¹⁴ 5d¹⁰ 6s¹'},
    'roentgenio': {'numero': 111, 'simbolo': 'Rg', 'masa': 282, 'tipo': 'Metal de transición', 'periodo': 7, 'estado': 'Desconocido','grupo':11, 'config': '5f¹⁴ 6d¹⁰ 7s¹'},

    #Grupo 12 (familia del zinc)
    'zinc': {'numero': 30, 'simbolo': 'Zn', 'masa': 65.38, 'tipo': 'Metal de transición', 'periodo': 4, 'estado': 'Sólido', 'grupo':12, 'config': '3d¹⁰ 4s²'},
    'cadmio': {'numero': 48, 'simbolo': 'Cd', 'masa': 112.41, 'tipo': 'Metal de transición', 'periodo': 5, 'estado': 'Sólido', 'grupo':12,'config': '4d¹⁰ 5s²'},
    'mercurio': {'numero': 80, 'simbolo': 'Hg', 'masa': 200.59, 'tipo': 'Metal de transición', 'periodo': 6, 'estado': 'Líquido', 'grupo':12, 'config': '4f¹⁴ 5d¹⁰ 6s²'},
    'copernicio': {'numero': 112, 'simbolo': 'Cn', 'masa': 285, 'tipo': 'Metal de transición', 'periodo': 7, 'estado': 'Desconocido', 'grupo':12,'config': '5f¹⁴ 6d¹⁰ 7s²'},

    #Grupo 13 (familia del boro)
    'boro': {'numero': 5, 'simbolo': 'B', 'masa': 10.81, 'grupo': 'Metaloide', 'periodo': 2, 'estado': 'Sólido', 'grupo':13,'config': '2s² 2p¹'},
    'aluminio': {'numero': 13, 'simbolo': 'Al', 'masa': 26.982, 'grupo': 'Metal', 'periodo': 3, 'estado': 'Sólido', 'grupo':13,'config': '3s² 3p¹'},
    'galio': {'numero': 31, 'simbolo': 'Ga', 'masa': 69.723, 'tipo': 'Metal', 'periodo': 4, 'estado': 'Sólido','grupo':13, 'config': '3d¹⁰ 4s² 4p¹'},
    'indio': {'numero': 49, 'simbolo': 'In', 'masa': 114.82, 'tipo': 'Metal', 'periodo': 5, 'estado': 'Sólido',  'grupo':13,'config': '4d¹⁰ 5s² 5p¹'},
    'talio': {'numero': 81, 'simbolo': 'Tl', 'masa': 204.38, 'tipo': 'Metal', 'periodo': 6, 'estado': 'Sólido', 'grupo':13,'config': '4f¹⁴ 5d¹⁰ 6s² 6p¹'},
    'nihonio': {'numero': 113, 'simbolo': 'Nh', 'masa': 286, 'tipo': 'Metal', 'periodo': 7, 'estado': 'Desconocido', 'grupo':13, 'config': '5f¹⁴ 6d¹⁰ 7s² 7p¹'},

     #Grupo 14 (Carbonoides)
    'carbono': {'numero': 6, 'simbolo': 'C', 'masa': 12.011, 'tipo': 'No metal', 'periodo': 2, 'estado': 'Sólido', 'grupo':14,'config': '2s² 2p²'},
    'silicio': {'numero': 14, 'simbolo': 'Si', 'masa': 28.085, 'tipo': 'Metaloide', 'periodo': 3, 'estado': 'Sólido','grupo':14, 'config': '3s² 3p²'},
    'germanio': {'numero': 32, 'simbolo': 'Ge', 'masa': 72.63, 'tipo': 'Metaloide', 'periodo': 4, 'estado': 'Sólido','grupo':14, 'config': '3d¹⁰ 4s² 4p²'},
    'estaño': {'numero': 50, 'simbolo': 'Sn', 'masa': 118.71, 'tipo': 'Metal', 'periodo': 5, 'estado': 'Sólido', 'grupo':14,'config': '4d¹⁰ 5s² 5p²'},
    'plomo': {'numero': 82, 'simbolo': 'Pb', 'masa': 207.2, 'tipo': 'Metal', 'periodo': 6, 'estado': 'Sólido','grupo':14, 'config': '4f¹⁴ 5d¹⁰ 6s² 6p²'},
    'flerovio': {'numero': 114, 'simbolo': 'Fl', 'masa': 289, 'tipo': 'Metal', 'periodo': 7, 'estado': 'Desconocido','grupo':14, 'config': '5f¹⁴ 6d¹⁰ 7s² 7p²'},

    # Grupo 15 (Nitrogenoides)
    'nitrogeno': {'numero': 7, 'simbolo': 'N', 'masa': 14.007, 'tipo': 'No metal', 'periodo': 2, 'estado': 'Gas', 'grupo':15,'config': '2s² 2p³'},
    'fósforo': {'numero': 15, 'simbolo': 'P', 'masa': 30.974, 'tipo': 'No metal', 'periodo': 3, 'estado': 'Sólido', 'grupo':15,'config': '3s² 3p³'},
    'arsénico': {'numero': 33, 'simbolo': 'As', 'masa': 74.922, 'tipo': 'Metaloide', 'periodo': 4, 'estado': 'Sólido','grupo':15, 'config': '3d¹⁰ 4s² 4p³'},
    'antimonio': {'numero': 51, 'simbolo': 'Sb', 'masa': 121.76, 'tipo': 'Metaloide', 'periodo': 5, 'estado': 'Sólido', 'grupo':15, 'config': '4d¹⁰ 5s² 5p³'},
    'bismuto': {'numero': 83, 'simbolo': 'Bi', 'masa': 208.98, 'tipo': 'Metal', 'periodo': 6, 'estado': 'Sólido','grupo':15, 'config': '4f¹⁴ 5d¹⁰ 6s² 6p³'},
    'moscovio': {'numero': 115, 'simbolo': 'Mc', 'masa': 290, 'tipo': 'Metal', 'periodo': 7, 'estado': 'Desconocido', 'grupo':15,'config': '5f¹⁴ 6d¹⁰ 7s² 7p³'},

     # Grupo 16 (Calcógenos)
    'oxigeno': {'numero': 8, 'simbolo': 'O', 'masa': 15.999, 'tipo': 'No metal', 'periodo': 2, 'estado': 'Gas', 'grupo':16,'config': '1s² 2s² 2p⁴'},
    'azufre': {'numero': 16, 'simbolo': 'S', 'masa': 32.06, 'tipo': 'No metal', 'periodo': 3, 'estado': 'Sólido', 'grupo':16,'config': '1s² 2s² 2p⁶ 3s² 3p⁴'},
    'selenio': {'numero': 34, 'simbolo': 'Se', 'masa': 78.971, 'tipo': 'No metal', 'periodo': 4, 'estado': 'Sólido', 'grupo':16,'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁴'},
    'telurio': {'numero': 52, 'simbolo': 'Te', 'masa': 127.6, 'tipo': 'Metaloide', 'periodo': 5, 'estado': 'Sólido', 'grupo':16,'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶ 5s² 4d¹⁰ 5p⁴'},
    'polonio': {'numero': 84, 'simbolo': 'Po', 'masa': 209, 'tipo': 'Metal', 'periodo': 6, 'estado': 'Sólido','grupo':16, 'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶ 5s² 4d¹⁰ 5p⁶ 6s² 4f¹⁴ 5d¹⁰ 6p⁴'},
    'livermorio': {'numero': 116, 'simbolo': 'Lv', 'masa': 293, 'tipo': 'Metal', 'periodo': 7, 'estado': 'Desconocido','grupo':16,'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶ 5s² 4d¹⁰ 5p⁶ 6s² 4f¹⁴ 5d¹⁰ 6p⁶ 7s² 5f¹⁴ 6d¹⁰ 7p⁴'},

     # Grupo 17 (Halógenos)
    'fluor': {'numero': 9, 'simbolo': 'F', 'masa': 18.998, 'tipo': 'No metal', 'periodo': 2, 'estado': 'Gas', 'grupo':17,'config': '1s² 2s² 2p⁵'},
    'cloro': {'numero': 17, 'simbolo': 'Cl', 'masa': 35.45, 'tipo': 'No metal', 'periodo': 3, 'estado': 'Gas', 'grupo':17, 'config': '1s² 2s² 2p⁶ 3s² 3p⁵'},
    'bromo': {'numero': 35, 'simbolo': 'Br', 'masa': 79.904, 'tipo': 'No metal', 'periodo': 4, 'estado': 'Líquido', 'grupo':17,'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁵'},
    'yodo': {'numero': 53, 'simbolo': 'I', 'masa': 126.9, 'tipo': 'No metal', 'periodo': 5, 'estado': 'Sólido','grupo':17,  'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶ 5s² 4d¹⁰ 5p⁵'},
    'astato': {'numero': 85, 'simbolo': 'At', 'masa': 210, 'tipo': 'Metaloide', 'periodo': 6, 'estado': 'Sólido', 'grupo':17,'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶ 5s² 4d¹⁰ 5p⁶ 6s² 4f¹⁴ 5d¹⁰ 6p⁵'},
    'tenesino': {'numero': 117, 'simbolo': 'Ts', 'masa': 294, 'tipo': 'Metal', 'periodo': 7, 'estado': 'Desconocido','grupo':17,'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶ 5s² 4d¹⁰ 5p⁶ 6s² 4f¹⁴ 5d¹⁰ 6p⁶ 7s² 5f¹⁴ 6d¹⁰ 7p⁵'},

    # Grupo 18 (Gases Nobles)
    'helio': {'numero': 2, 'simbolo': 'He', 'masa': 4.0026, 'tipo': 'Gas noble', 'periodo': 1, 'estado': 'Gas', 'grupo':18, 'config': '1s²'},
    'neon': {'numero': 10, 'simbolo': 'Ne', 'masa': 20.18, 'tipo': 'Gas noble', 'periodo': 2, 'estado': 'Gas', 'grupo':18, 'config': '1s² 2s² 2p⁶'},
    'argón': {'numero': 18, 'simbolo': 'Ar', 'masa': 39.948, 'tipo': 'Gas noble', 'periodo': 3, 'estado': 'Gas', 'grupo':18, 'config': '1s² 2s² 2p⁶ 3s² 3p⁶'},
    'kriptón': {'numero': 36, 'simbolo': 'Kr', 'masa': 83.798, 'tipo': 'Gas noble', 'periodo': 4, 'estado': 'Gas', 'grupo':18,  'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶'},
    'xenón': {'numero': 54, 'simbolo': 'Xe', 'masa': 131.293, 'tipo': 'Gas noble', 'periodo': 5, 'estado': 'Gas', 'grupo':18, 'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶ 5s² 4d¹⁰ 5p⁶'},
    'radón': {'numero': 86, 'simbolo': 'Rn', 'masa': 222, 'tipo': 'Gas noble', 'periodo': 6, 'estado': 'Gas', 'grupo':18, 'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶ 5s² 4d¹⁰ 5p⁶ 6s² 4f¹⁴ 5d¹⁰ 6p⁶'},
    'oganesson': {'numero': 118, 'simbolo': 'Og', 'masa': 294, 'tipo': 'Gas noble', 'periodo': 7, 'estado': 'Desconocido', 'grupo':18, 'config': '1s² 2s² 2p⁶ 3s² 3p⁶ 4s² 3d¹⁰ 4p⁶ 5s² 4d¹⁰ 5p⁶ 6s² 4f¹⁴ 5d¹⁰ 6p⁶ 7s² 5f¹⁴ 6d¹⁰ 7p⁶'},

    # Lantánidos (Periodo 6)
    'lantano': {'numero': 57, 'simbolo': 'La', 'masa': 138.91, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido',  'grupo': 'Lantánidos (Periodo 6)',  'config': '5d¹ 6s²'},
    'cerio': {'numero': 58, 'simbolo': 'Ce', 'masa': 140.91, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido', 'grupo': 'Lantánidos (Periodo 6)', 'config': '4f¹ 5d¹ 6s²'},
    'praseodimio': {'numero': 59, 'simbolo': 'Pr', 'masa': 140.91, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido', 'grupo': 'Lantánidos (Periodo 6)', 'config': '4f³ 6s²'},
    'neodimio': {'numero': 60, 'simbolo': 'Nd', 'masa': 144.24, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido', 'grupo': 'Lantánidos (Periodo 6)',  'config': '4f⁴ 6s²'},
    'prometio': {'numero': 61, 'simbolo': 'Pm', 'masa': 145, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido','grupo': 'Lantánidos (Periodo 6)',  'config': '4f⁵ 6s²'},
    'samario': {'numero': 62, 'simbolo': 'Sm', 'masa': 150.36, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido', 'grupo': 'Lantánidos (Periodo 6)', 'config': '4f⁶ 6s²'},
    'europio': {'numero': 63, 'simbolo': 'Eu', 'masa': 151.96, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido','grupo': 'Lantánidos (Periodo 6)', 'config': '4f⁷ 6s²'},
    'gadolinio': {'numero': 64, 'simbolo': 'Gd', 'masa': 157.25, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido', 'grupo': 'Lantánidos (Periodo 6)', 'config': '4f⁷ 5d¹ 6s²'},
    'terbio': {'numero': 65, 'simbolo': 'Tb', 'masa': 158.93, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido','grupo': 'Lantánidos (Periodo 6)', 'config': '4f⁹ 6s²'},
    'disprosio': {'numero': 66, 'simbolo': 'Dy', 'masa': 162.5, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido','grupo': 'Lantánidos (Periodo 6)',  'config': '4f¹⁰ 6s²'},
    'holmio': {'numero': 67, 'simbolo': 'Ho', 'masa': 164.93, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido','grupo': 'Lantánidos (Periodo 6)', 'config': '4f¹¹ 6s²'},
    'erbio': {'numero': 68, 'simbolo': 'Er', 'masa': 167.26, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido','grupo': 'Lantánidos (Periodo 6)', 'config': '4f¹² 6s²'},
    'tulio': {'numero': 69, 'simbolo': 'Tm', 'masa': 168.93, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido','grupo': 'Lantánidos (Periodo 6)', 'config': '4f¹³ 6s²'},
    'iterbio': {'numero': 70, 'simbolo': 'Yb', 'masa': 173.05, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido','grupo': 'Lantánidos (Periodo 6)', 'config': '4f¹⁴ 6s²'},
    'lutecio': {'numero': 71, 'simbolo': 'Lu', 'masa': 174.97, 'tipo': 'Lantánido', 'periodo': 6, 'estado': 'Sólido','grupo': 'Lantánidos (Periodo 6)', 'config': '4f¹⁴ 5d¹ 6s²'},

     # Actínidos (Periodo 7)
    'actinio': {'numero': 89, 'simbolo': 'Ac', 'masa': 227, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido', 'grupo': 'Actínidos (Periodo 7)', 'config': '6d¹ 7s²'},
    'torio': {'numero': 90, 'simbolo': 'Th', 'masa': 232.04, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido', 'grupo': 'Actínidos (Periodo 7)', 'config': '6d² 7s²'},
    'protactinio': {'numero': 91, 'simbolo': 'Pa', 'masa': 231.04, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido','grupo': 'Actínidos (Periodo 7)',  'config': '5f² 6d¹ 7s²'},
    'uranio': {'numero': 92, 'simbolo': 'U', 'masa': 238.03, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido', 'grupo': 'Actínidos (Periodo 7)', 'config': '5f³ 6d¹ 7s²'},
    'neptunio': {'numero': 93, 'simbolo': 'Np', 'masa': 237, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido', 'grupo': 'Actínidos (Periodo 7)', 'config': ' 5f⁴ 6d¹ 7s²'},
    'plutonio': {'numero': 94, 'simbolo': 'Pu', 'masa': 244, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido', 'grupo': 'Actínidos (Periodo 7)', 'config': '5f⁶ 7s²'},
    'americio': {'numero': 95, 'simbolo': 'Am', 'masa': 243, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido','grupo': 'Actínidos (Periodo 7)',  'config': '5f⁷ 7s²'},
    'curio': {'numero': 96, 'simbolo': 'Cm', 'masa': 247, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido', 'grupo': 'Actínidos (Periodo 7)', 'config': '5f⁷ 6d¹ 7s²'},
    'berkelio': {'numero': 97, 'simbolo': 'Bk', 'masa': 247, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido', 'grupo': 'Actínidos (Periodo 7)', 'config': '5f⁹ 7s²'},
    'californio': {'numero': 98, 'simbolo': 'Cf', 'masa': 251, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido','grupo': 'Actínidos (Periodo 7)',  'config': ' 5f¹⁰ 7s²'},
    'einstenio': {'numero': 99, 'simbolo': 'Es', 'masa': 252, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sólido', 'grupo': 'Actínidos (Periodo 7)', 'config': '5f¹¹ 7s²'},
    'fermio': {'numero': 100, 'simbolo': 'Fm', 'masa': 257, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sintético','grupo': 'Actínidos (Periodo 7)',  'config': '5f¹² 7s²'},
    'mendelevio': {'numero': 101, 'simbolo': 'Md', 'masa': 258, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sintético','grupo': 'Actínidos (Periodo 7)',  'config': '5f¹³ 7s²'},
    'nobelio': {'numero': 102, 'simbolo': 'No', 'masa': 259, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sintético','grupo': 'Actínidos (Periodo 7)',  'config': '5f¹⁴ 7s²'},
    'laurencio': {'numero': 103, 'simbolo': 'Lr', 'masa': 266, 'tipo': 'Actínido', 'periodo': 7, 'estado': 'Sintético', 'grupo': 'Actínidos (Periodo 7)', 'config': '5f¹⁴ 6d¹ 7s²'},
}

print(f"¡Base de datos COMPLETA cargada con {len(elementos)} elementos!")
# Out:
# ¡Base de datos COMPLETA cargada con 118 elementos!

# %%
def mostrar_elemento(nombre):
    datos = elementos[nombre]
    print(f"\n{' INFORMACIÓN DETALLADA '.center(50, '=')}")
    print(f"Nombre: {nombre.capitalize()}")
    print(f"Símbolo: {datos['simbolo']}")
    print(f"Número atómico: {datos['numero']}")
    print(f"Masa atómica: {datos['masa']}")
    print(f"Grupo: {datos['grupo']}")
    print(f"Periodo: {datos['periodo']}")
    print(f"Estado: {datos['estado']}")
    print(f"Tipo: {datos['tipo']}")
    print(f"Configuracion: {datos['config']}")
  
    print("="*50)

# %%
#Diccionario
diccionario = {
    'número atómico': 'Número de protones (partícula pequeña de materia con carga positiva ) en el núcleo de un átomo.',
    'masa atómica': 'Masa promedio de los átomos de un elemento en unidades de masa atómica (u).',
    'grupo': 'Columna en la tabla periódica que indica la cantidad de electrones de valencia.',
    'periodo': 'Fila en la tabla periódica que indica el número de niveles de energía.',
    'estado': 'Fase de la materia a 25°C (gas, líquido o sólido).',
    'configuración': 'Describe donde están ubicados los electrones (partícula con carga eléctrica negativa) en un átomo, especificando los niveles y subniveles de energía donde se encuentran.', 
    'metales': 'Elementos brillantes, conducen bien el calor y la electricidad y se pueden doblar sin romperse.',
    'no metales': 'Elementos opacos, no conducen bien la electricidad y son frágiles.',
    'metaloides': 'Están entre metales y no metales.',
    'gases nobles': 'Gases que casi no reaccionan.',
    'lantánidos y actínidos': 'Metales especiales del bloque f, o sea metales raros usados en tecnología e industria nuclear, ubicados separados en la tabla periódica.'
}

def mostrar_diccionario():
    print("\n" + " DICCIONARIO DE TÉRMINOS ".center(50, '='))
    for termino, definicion in diccionario.items():
        print(f"\n- {termino.capitalize()}: {definicion}")
    print("\n" + "="*50)

# %%
 def consultar_tabla_periodica():
    print("\n" + " TABLA PERIÓDICA COMPLETA ".center(50, '='))
    print("\nSi no entiendes algún término, puedes ir al diccionario para que te lo explique.")
    
    while True:
        print("\nOpciones:")
        print("1. Buscar elemento por nombre")
        print("2. Ver diccionario de términos")
        print("3. Salir")
        
        opcion = input("Seleccione (1-3): ")
        
        if opcion == '1':
            nombre = input("\nNombre del elemento (todo en minúsculas y sin tilde): ").lower().strip()
            if nombre in elementos:
                mostrar_elemento(nombre)
            else:
                print("Elemento no encontrado. Intente nuevamente.")
        elif opcion == '2':
            mostrar_diccionario()
        elif opcion == '3':
            print("\n¡Hasta prooonto!")
            break
        else:
            print("Opción no válida. Intente nuevamente.")

# Llamada correcta a la función
consultar_tabla_periodica()
# Out:
# ============ TABLA PERIÓDICA COMPLETA ============
#
# Si no entiendes algún término, puedes ir al diccionario para que te lo explique.
#
# Opciones:
# 1. Buscar elemento por nombre
# 2. Ver diccionario de términos
# 3. Salir
# Seleccione (1-3):  3
# ¡Hasta pronto!
